# %%
import pandas as pd
df = pd.read_excel('measurement_data_0851~1100.xlsx')
# df1 = pd.read_excel('육안평가_대표_박병철.xlsx')

# %%
new_df = df.loc[df['subject_no'].isin([1066, 1067, 1071, 1072, 1073, 1074, 1075, 1076, 1077, 1078, 1079, 1080, 1081]), ['스팟개수_정면', '모공개수_오른쪽볼', '모공개수_왼쪽볼']]

# %%
name = ['에포트1', '에포트2', '서일송', '이한', '장희진', '이경호', '강다윤', '이은지', '강은수', '김다은', '아빠', '황형근', '누누']

# %%
[print(f"{name[idx]} => {item}개의 색소 침착 개수") for idx, item in enumerate(new_df['스팟개수_정면'])]
# Out:
# 에포트1 => 42개의 색소 침착 개수
# 에포트2 => 73개의 색소 침착 개수
# 서일송 => 111개의 색소 침착 개수
# 이한 => 133개의 색소 침착 개수
# 장희진 => 102개의 색소 침착 개수
# 이경호 => 114개의 색소 침착 개수
# 강다윤 => 124개의 색소 침착 개수
# 이은지 => 142개의 색소 침착 개수
# 강은수 => 96개의 색소 침착 개수
# 김다은 => 129개의 색소 침착 개수
# 아빠 => 222개의 색소 침착 개수
# 황형근 => 127개의 색소 침착 개수
# 누누 => 86개의 색소 침착 개수
# [None, None, None, None, None, None, None, None, None, None, None, None, None]

# %%
[print(f"{name[idx]} => {item}개의 모공개수_오른쪽볼") for idx, item in enumerate(new_df['모공개수_오른쪽볼'])]
[print(f"{name[idx]} => {item}개의 모공개수_왼쪽볼") for idx, item in enumerate(new_df['모공개수_왼쪽볼'])]
# Out:
# 에포트1 => 484개의 모공개수_오른쪽볼
# 에포트2 => 580개의 모공개수_오른쪽볼
# 서일송 => 975개의 모공개수_오른쪽볼
# 이한 => 836개의 모공개수_오른쪽볼
# 장희진 => 660개의 모공개수_오른쪽볼
# 이경호 => 582개의 모공개수_오른쪽볼
# 강다윤 => 1004개의 모공개수_오른쪽볼
# 이은지 => 1171개의 모공개수_오른쪽볼
# 강은수 => 753개의 모공개수_오른쪽볼
# 김다은 => 630개의 모공개수_오른쪽볼
# 아빠 => 1050개의 모공개수_오른쪽볼
# 황형근 => 1435개의 모공개수_오른쪽볼
# 누누 => 953개의 모공개수_오른쪽볼
# 에포트1 => 414개의 모공개수_왼쪽볼
# 에포트2 => 410개의 모공개수_왼쪽볼
# 서일송 => 822개의 모공개수_왼쪽볼
# 이한 => 781개의 모공개수_왼쪽볼
# 장희진 => 525개의 모공개수_왼쪽볼
# 이경호 => 499개의 모공개수_왼쪽볼
# 강다윤 => 985개의 모공개수_왼쪽볼
# 이은지 => 1111개의 모공개수_왼쪽볼
# 강은수 => 752개의 모공개수_왼쪽볼
# 김다은 => 573개의 모공개수_왼쪽볼
# 아빠 => 1027개의 모공개수_왼쪽볼
# 황형근 => 1294개의 모공개수_왼쪽볼
# 누누 => 1139개의 모공개수_왼쪽볼
# [None, None, None, None, None, None, None, None, None, None, None, None, None]

# %%
df.loc[df['subject_no'].isin([1066, 1067, 1071, 1072, 1073, 1074, 1075, 1076, 1077, 1078, 1079, 1080, 1081]), :]
# Out:
#      subject_no      수분_이마    수분_오른쪽볼     수분_왼쪽볼       수분_턱  탄력_턱_R0  탄력_턱_R1  \
# 215        1066  87.333333  91.333333  86.000000  83.333333    0.383    0.073
# 216        1067  84.666667  81.666667  87.333333  90.333333    0.295    0.074
# 220        1071  79.000000  84.000000  82.666667  90.333333    0.209    0.077
# 221        1072  63.666667  86.000000  87.666667  69.000000    0.282    0.077
# 222        1073  70.333333  77.333333  79.666667  85.000000    0.311    0.115
# 223        1074  70.333333  62.333333  64.000000  52.333333    0.302    0.070
# 224        1075  67.333333  73.000000  74.333333  70.333333    0.249    0.074
# 225        1076  76.666667  80.000000  82.666667  87.333333    0.240    0.085
# 226        1077  66.000000  66.333333  69.333333  79.000000    0.331    0.063
# 227        1078  74.666667  86.333333  82.666667  74.666667    0.247    0.076
# 228        1079  57.000000  69.333333  71.333333  70.333333    0.293    0.110
# ...
